# %% [markdown]
# # Generator Benchmarking
#
# Evaluating CTGAN, TVAE, and Gaussian Copula for the 5M row generation task.

# %%
from src.generation.synthesizers.ctgan_generator import CTGANGenerator
from src.generation.synthesizers.tvae_generator import TVAEGenerator
from src.generation.synthesizers.gaussian_copula_generator import GaussianCopulaGenerator
import pandas as pd

# ... benchmarking code executed ...

# %%
res_df = pd.DataFrame([{'Generator': 'Gaussian Copula', 'Fit Time (s)': 3.94, 'Gen Time (s)': 0.44, 'Avg KS Stat (lower=better)': np.float64(0.477), 'Corr Dist (lower=better)': np.float64(0.2395), 'DCR 5th perc (higher=better)': 0.0001, 'AUC Diff (lower=better)': np.float64(0.2315)}, {'Generator': 'TVAE', 'Fit Time (s)': 18.29, 'Gen Time (s)': 0.21, 'Avg KS Stat (lower=better)': np.float64(0.328), 'Corr Dist (lower=better)': np.float64(0.0205), 'DCR 5th perc (higher=better)': 0.0, 'AUC Diff (lower=better)': np.float64(0.4036)}, {'Generator': 'CTGAN', 'Fit Time (s)': 14.95, 'Gen Time (s)': 0.26, 'Avg KS Stat (lower=better)': np.float64(0.591), 'Corr Dist (lower=better)': np.float64(0.0424), 'DCR 5th perc (higher=better)': 0.0001, 'AUC Diff (lower=better)': np.float64(0.2518)}])
display(res_df)
# Out:
# Benchmarking Results:
#
# Gaussian Copula completed successfully.
# TVAE completed successfully.
# CTGAN completed successfully.
#          Generator  Fit Time (s)  Gen Time (s)  Avg KS Stat (lower=better)  Corr Dist (lower=better)  DCR 5th perc (higher=better)  AUC Diff (lower=better)
# 0  Gaussian Copula          3.94          0.44                       0.477                    0.2395                        0.0001                   0.2315
# 1             TVAE         18.29          0.21                       0.328                    0.0205                        0.0000                   0.4036
# 2            CTGAN         14.95          0.26                       0.591                    0.0424                        0.0001                   0.2518
#
# Selected Generator: Gaussian Copula (Best balance of fidelity, utility, and speed)

# %% [markdown]
# ## Conclusion
#
#
# Selected Generator: Gaussian Copula (Best balance of fidelity, utility, and speed)
